# %%
import pandas as pd

# %%
series= pd.Series(["BMW", "Toyata"])

# %%
series
# Out:
# 0       BMW
# 1    Toyata
# dtype: object

# %%
colours = pd.Series(["Red", "Blue"])

# %%
colours
# Out:
# 0     Red
# 1    Blue
# dtype: object

# %%
car_data = pd.DataFrame({"Car make": series, "Color": colours})

# %%
car_data
# Out:
#   Car make Color
# 0      BMW   Red
# 1   Toyata  Blue

# %%
car_sales = pd.read_csv("car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# #Export dataframe

# %%
car_sales.to_csv("Exported-car-sales.csv", index = False)

# %% [markdown]
# Describe Data

# %%
#Attributes
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_columns = car_sales.columns

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
car_sales.mean(numeric_only=True)
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_sales["Doors"].sum()
# Out:
# 40

# %%
len(car_sales)
# Out:
# 10

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# Viweing and selecting data

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.head(9)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00

# %%
animals = pd.Series(["cat", "dog", "bird", "human", "bat"], index=[0, 3, 9, 3, 9])

# %%
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 3    human
# 9      bat
# dtype: object

# %%
#loc is the index
animals.loc[3]
# Out:
# 3      dog
# 3    human
# dtype: object

# %%
#iloc is position
animals.iloc[3]
# Out:
# 'human'

# %%
animals.iloc[:3]
# Out:
# 0     cat
# 3     dog
# 9    bird
# dtype: object

# %%
car_sales.loc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
  car_sales["Colour"]
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales[car_sales["Odometer (KM)"]>100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
#Group by 
car_sales.groupby(["Make"]).mean(numeric_only=True)
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales["Odometer (KM)"].plot()
# Out:
# <Axes: >

# %%
car_sales.hist()
# Out:
# array([[<Axes: title={'center': 'Odometer (KM)'}>,
#         <Axes: title={'center': 'Doors'}>]], dtype=object)

# %%
car_sales["Odometer (KM)"].hist()
# Out:
# <Axes: >

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\, \.]' , '', regex= True)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# C:\Users\shiti\AppData\Local\Temp\ipykernel_3936\2385724091.py:1: SyntaxWarning: invalid escape sequence '\$'
#   car_sales["Price"] = car_sales["Price"].str.replace('[\$\, \.]' , '', regex= True)

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '', regex=True)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# C:\Users\shiti\AppData\Local\Temp\ipykernel_3936\2724684380.py:1: SyntaxWarning: invalid escape sequence '\$'
#   car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '', regex=True)

# %%
car_sales['Price'] = car_sales['Price'].replace('[$,.]', '', regex=True).astype(int)

# %%
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price             int32
# dtype: object

# %%
car_sales["Price"].hist()
# Out:
# <Axes: >

# %% [markdown]
# Manipulating Data

# %%
car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales["Make"] = car_sales["Make"].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   400000
# 1   honda    Red          87899      4   500000
# 2  toyota   Blue          32549      3   700000
# 3     bmw  Black          11179      5  2200000
# 4  nissan  White         213095      4   350000
# 5  toyota  Green          99213      4   450000
# 6   honda   Blue          45698      4   750000
# 7   honda   Blue          54738      4   700000
# 8  toyota  White          60000      4   625000
# 9  nissan  White          31600      4   970000

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"]=car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(numeric_only=True))

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(numeric_only=True), inplace=True)
# Out:
# C:\Users\shiti\AppData\Local\Temp\ipykernel_3936\1694831493.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(numeric_only=True), inplace=True)

# %%
car_sales_missing.fillna({"Odometer":car_sales_missing["Odometer"].mean(numeric_only=True)}, inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna(inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
#Column from series
seats_column = pd.Series([5, 5, 5, 5, 5, 5])

car_sales["Seats"] = seats_column

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   400000    5.0
# 1   honda    Red          87899      4   500000    5.0
# 2  toyota   Blue          32549      3   700000    5.0
# 3     bmw  Black          11179      5  2200000    5.0
# 4  nissan  White         213095      4   350000    5.0
# 5  toyota  Green          99213      4   450000    5.0
# 6   honda   Blue          45698      4   750000    NaN
# 7   honda   Blue          54738      4   700000    NaN
# 8  toyota  White          60000      4   625000    NaN
# 9  nissan  White          31600      4   970000    NaN

# %%
car_sales.fillna({["Seats"]:5}, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 car_sales.fillna({["Seats"]:5}, inplace=True)
#
# TypeError: unhashable type: 'list'

# %%
car_sales.fillna({"Seats": 5}, inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   400000    5.0
# 1   honda    Red          87899      4   500000    5.0
# 2  toyota   Blue          32549      3   700000    5.0
# 3     bmw  Black          11179      5  2200000    5.0
# 4  nissan  White         213095      4   350000    5.0
# 5  toyota  Green          99213      4   450000    5.0
# 6   honda   Blue          45698      4   750000    5.0
# 7   honda   Blue          54738      4   700000    5.0
# 8  toyota  White          60000      4   625000    5.0
# 9  nissan  White          31600      4   970000    5.0

# %%
#column from python list
fuel_economy = [7.5, 9.2, 5, 9.6, 8.6, 6, 7, 8, 9, 10]

# %%
car_sales["Fuel per 100km"] = fuel_economy

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100km
# 0  toyota  White         150043      4   400000    5.0             7.5
# 1   honda    Red          87899      4   500000    5.0             9.2
# 2  toyota   Blue          32549      3   700000    5.0             5.0
# 3     bmw  Black          11179      5  2200000    5.0             9.6
# 4  nissan  White         213095      4   350000    5.0             8.6
# 5  toyota  Green          99213      4   450000    5.0             6.0
# 6   honda   Blue          45698      4   750000    5.0             7.0
# 7   honda   Blue          54738      4   700000    5.0             8.0
# 8  toyota  White          60000      4   625000    5.0             9.0
# 9  nissan  White          31600      4   970000    5.0            10.0

# %%
car_sales["Total Fuel used"] = car_sales["Odometer (KM)"]/100 * car_sales["Fuel per 100km"]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100km  \
# 0  toyota  White         150043      4   400000    5.0             7.5
# 1   honda    Red          87899      4   500000    5.0             9.2
# 2  toyota   Blue          32549      3   700000    5.0             5.0
# 3     bmw  Black          11179      5  2200000    5.0             9.6
# 4  nissan  White         213095      4   350000    5.0             8.6
# 5  toyota  Green          99213      4   450000    5.0             6.0
# 6   honda   Blue          45698      4   750000    5.0             7.0
# 7   honda   Blue          54738      4   700000    5.0             8.0
# 8  toyota  White          60000      4   625000    5.0             9.0
# 9  nissan  White          31600      4   970000    5.0            10.0
#
#    Total Fuel used
# 0        11253.225
# 1         8086.708
# 2         1627.450
# 3         1073.184
# 4        18326.170
# 5         5952.780
# 6         3198.860
# 7         4379.040
# 8         5400.000
# 9         3160.000

# %%
car_sales["Number of wheels"] = 4

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100km  \
# 0  toyota  White         150043      4   400000    5.0             7.5
# 1   honda    Red          87899      4   500000    5.0             9.2
# 2  toyota   Blue          32549      3   700000    5.0             5.0
# 3     bmw  Black          11179      5  2200000    5.0             9.6
# 4  nissan  White         213095      4   350000    5.0             8.6
# 5  toyota  Green          99213      4   450000    5.0             6.0
# 6   honda   Blue          45698      4   750000    5.0             7.0
# 7   honda   Blue          54738      4   700000    5.0             8.0
# 8  toyota  White          60000      4   625000    5.0             9.0
# 9  nissan  White          31600      4   970000    5.0            10.0
#
#    Total Fuel used  Number of wheels
# 0        11253.225                 4
# 1         8086.708                 4
# 2         1627.450                 4
# 3         1073.184                 4
# 4        18326.170                 4
# 5         5952.780                 4
# 6         3198.860                 4
# 7         4379.040                 4
# 8         5400.000                 4
# 9         3160.000                 4

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100km  \
# 0  toyota  White         150043      4   400000    5.0             7.5
# 1   honda    Red          87899      4   500000    5.0             9.2
# 2  toyota   Blue          32549      3   700000    5.0             5.0
# 3     bmw  Black          11179      5  2200000    5.0             9.6
# 4  nissan  White         213095      4   350000    5.0             8.6
# 5  toyota  Green          99213      4   450000    5.0             6.0
# 6   honda   Blue          45698      4   750000    5.0             7.0
# 7   honda   Blue          54738      4   700000    5.0             8.0
# 8  toyota  White          60000      4   625000    5.0             9.0
# 9  nissan  White          31600      4   970000    5.0            10.0
#
#    Total Fuel used  Number of wheels
# 0        11253.225                 4
# 1         8086.708                 4
# 2         1627.450                 4
# 3         1073.184                 4
# 4        18326.170                 4
# 5         5952.780                 4
# 6         3198.860                 4
# 7         4379.040                 4
# 8         5400.000                 4
# 9         3160.000                 4

# %%
car_sales.dtypes
# Out:
# Make                 object
# Colour               object
# Odometer (KM)         int64
# Doors                 int64
# Price                 int32
# Seats               float64
# Fuel per 100km      float64
# Total Fuel used     float64
# Number of wheels      int64
# dtype: object

# %%
car_sales.sample(frac=0.5)
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Seats  Fuel per 100km  \
# 9  nissan  White          31600      4  970000    5.0            10.0
# 7   honda   Blue          54738      4  700000    5.0             8.0
# 8  toyota  White          60000      4  625000    5.0             9.0
# 6   honda   Blue          45698      4  750000    5.0             7.0
# 5  toyota  Green          99213      4  450000    5.0             6.0
#
#    Total Fuel used  Number of wheels
# 9          3160.00                 4
# 7          4379.04                 4
# 8          5400.00                 4
# 6          3198.86                 4
# 5          5952.78                 4

# %%
car_sales.sample(frac=1)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100km  \
# 3     bmw  Black          11179      5  2200000    5.0             9.6
# 1   honda    Red          87899      4   500000    5.0             9.2
# 7   honda   Blue          54738      4   700000    5.0             8.0
# 8  toyota  White          60000      4   625000    5.0             9.0
# 5  toyota  Green          99213      4   450000    5.0             6.0
# 6   honda   Blue          45698      4   750000    5.0             7.0
# 9  nissan  White          31600      4   970000    5.0            10.0
# 0  toyota  White         150043      4   400000    5.0             7.5
# 2  toyota   Blue          32549      3   700000    5.0             5.0
# 4  nissan  White         213095      4   350000    5.0             8.6
#
#    Total Fuel used  Number of wheels
# 3         1073.184                 4
# 1         8086.708                 4
# 7         4379.040                 4
# 8         5400.000                 4
# 5         5952.780                 4
# 6         3198.860                 4
# 9         3160.000                 4
# 0        11253.225                 4
# 2         1627.450                 4
# 4        18326.170                 4

# %%
car_sales_shuffle = car_sales.sample(frac=1)

# %%
car_sales_shuffle
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100km  \
# 4  nissan  White         213095      4   350000    5.0             8.6
# 6   honda   Blue          45698      4   750000    5.0             7.0
# 0  toyota  White         150043      4   400000    5.0             7.5
# 2  toyota   Blue          32549      3   700000    5.0             5.0
# 9  nissan  White          31600      4   970000    5.0            10.0
# 1   honda    Red          87899      4   500000    5.0             9.2
# 3     bmw  Black          11179      5  2200000    5.0             9.6
# 7   honda   Blue          54738      4   700000    5.0             8.0
# 8  toyota  White          60000      4   625000    5.0             9.0
# 5  toyota  Green          99213      4   450000    5.0             6.0
#
#    Total Fuel used  Number of wheels
# 4        18326.170                 4
# 6         3198.860                 4
# 0        11253.225                 4
# 2         1627.450                 4
# 9         3160.000                 4
# 1         8086.708                 4
# 3         1073.184                 4
# 7         4379.040                 4
# 8         5400.000                 4
# 5         5952.780                 4

# %%
car_sales_shuffle.sample(frac=0.2)
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Seats  Fuel per 100km  \
# 7   honda   Blue          54738      4  700000    5.0             8.0
# 5  toyota  Green          99213      4  450000    5.0             6.0
#
#    Total Fuel used  Number of wheels
# 7          4379.04                 4
# 5          5952.78                 4

# %%
car_sales_shuffle.reset_index(drop=True, inplace=True)

# %%
car_sales_shuffle
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100km  \
# 0  nissan  White         213095      4   350000    5.0             8.6
# 1   honda   Blue          45698      4   750000    5.0             7.0
# 2  toyota  White         150043      4   400000    5.0             7.5
# 3  toyota   Blue          32549      3   700000    5.0             5.0
# 4  nissan  White          31600      4   970000    5.0            10.0
# 5   honda    Red          87899      4   500000    5.0             9.2
# 6     bmw  Black          11179      5  2200000    5.0             9.6
# 7   honda   Blue          54738      4   700000    5.0             8.0
# 8  toyota  White          60000      4   625000    5.0             9.0
# 9  toyota  Green          99213      4   450000    5.0             6.0
#
#    Total Fuel used  Number of wheels
# 0        18326.170                 4
# 1         3198.860                 4
# 2        11253.225                 4
# 3         1627.450                 4
# 4         3160.000                 4
# 5         8086.708                 4
# 6         1073.184                 4
# 7         4379.040                 4
# 8         5400.000                 4
# 9         5952.780                 4

# %%
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply(lambda x:x/1.609)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100km  \
# 0  toyota  White   93252.330640      4   400000    5.0             7.5
# 1   honda    Red   54629.583592      4   500000    5.0             9.2
# 2  toyota   Blue   20229.334991      3   700000    5.0             5.0
# 3     bmw  Black    6947.793661      5  2200000    5.0             9.6
# 4  nissan  White  132439.403356      4   350000    5.0             8.6
# 5  toyota  Green   61661.280298      4   450000    5.0             6.0
# 6   honda   Blue   28401.491610      4   750000    5.0             7.0
# 7   honda   Blue   34019.888129      4   700000    5.0             8.0
# 8  toyota  White   37290.242387      4   625000    5.0             9.0
# 9  nissan  White   19639.527657      4   970000    5.0            10.0
#
#    Total Fuel used  Number of wheels
# 0        11253.225                 4
# 1         8086.708                 4
# 2         1627.450                 4
# 3         1073.184                 4
# 4        18326.170                 4
# 5         5952.780                 4
# 6         3198.860                 4
# 7         4379.040                 4
# 8         5400.000                 4
# 9         3160.000                 4

# %%
car_sales.rename(columns={"Odometer (KM)": "Odometer (Miles)"})
# Out:
#      Make Colour  Odometer (Miles)  Doors    Price  Seats  Fuel per 100km  \
# 0  toyota  White      93252.330640      4   400000    5.0             7.5
# 1   honda    Red      54629.583592      4   500000    5.0             9.2
# 2  toyota   Blue      20229.334991      3   700000    5.0             5.0
# 3     bmw  Black       6947.793661      5  2200000    5.0             9.6
# 4  nissan  White     132439.403356      4   350000    5.0             8.6
# 5  toyota  Green      61661.280298      4   450000    5.0             6.0
# 6   honda   Blue      28401.491610      4   750000    5.0             7.0
# 7   honda   Blue      34019.888129      4   700000    5.0             8.0
# 8  toyota  White      37290.242387      4   625000    5.0             9.0
# 9  nissan  White      19639.527657      4   970000    5.0            10.0
#
#    Total Fuel used  Number of wheels
# 0        11253.225                 4
# 1         8086.708                 4
# 2         1627.450                 4
# 3         1073.184                 4
# 4        18326.170                 4
# 5         5952.780                 4
# 6         3198.860                 4
# 7         4379.040                 4
# 8         5400.000                 4
# 9         3160.000                 4
